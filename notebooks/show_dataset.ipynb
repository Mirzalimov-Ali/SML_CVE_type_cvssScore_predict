# %%
import pandas as pd

# %% [markdown]
# # Fill Missing Values

# %%
df_fill = pd.read_csv('../data/filled/filled_dataset.csv')

# %%
df_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101685 entries, 0 to 101684
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   cve_id        101685 non-null  object
#  1   description   101685 non-null  object
#  2   cvss_score    101685 non-null  float64
#  3   cwe           101685 non-null  object
#  4   vendor        101685 non-null  object
#  5   product       101685 non-null  object
#  6   publish_date  101685 non-null  object
#  7   type          101685 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 6.2+ MB

# %%
df_fill['type'].unique()
# Out:
# array(['XSS', 'DoS', 'Other', 'InfoDisclosure', 'RCE', 'AuthBypass',
#        'SQLi', 'PathTraversal', 'SSRF', 'PrivEsc', 'CSRF'], dtype=object)

# %%
df_fc = pd.read_csv('../data/engineered/engineered_dataset.csv')

# %% [markdown]
# # Feature Creation

# %%
df_fc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101685 entries, 0 to 101684
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   cve_id                      101685 non-null  object
#  1   description                 101685 non-null  object
#  2   cvss_score                  101685 non-null  float64
#  3   cwe                         101685 non-null  object
#  4   vendor                      101685 non-null  object
#  5   product                     101685 non-null  object
#  6   publish_date                101685 non-null  object
#  7   type                        101685 non-null  object
#  8   cvss_bin_low                101685 non-null  int64
#  9   cvss_bin_medium             101685 non-null  int64
#  10  cvss_bin_high               101685 non-null  int64
#  11  vendor_freq                 101685 non-null  float64
#  12  product_freq                101685 non-null  float64
# ...

# %% [markdown]
# # Preprocessing

# %%
df_pre = pd.read_csv('../data/preprocessed/preprocessed_dataset.csv')

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101685 entries, 0 to 101684
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   cve_id                      101685 non-null  float64
#  1   description                 101685 non-null  float64
#  2   cvss_score                  101685 non-null  float64
#  3   cwe                         101685 non-null  float64
#  4   vendor                      101685 non-null  float64
#  5   product                     101685 non-null  float64
#  6   publish_date                101685 non-null  float64
#  7   type                        101685 non-null  float64
#  8   cvss_bin_low                101685 non-null  float64
#  9   cvss_bin_medium             101685 non-null  float64
#  10  cvss_bin_high               101685 non-null  float64
#  11  vendor_freq                 101685 non-null  float64
# ...
